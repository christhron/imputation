# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Reading the data

# %%
df = pd.read_csv(os.path.abspath('../data/Nal_filtre_FLX_NEE_01012011_31122017.csv'), encoding = "ISO-8859-1", sep = ';')
df.columns = df.iloc[0] # fix the col names to be the 1st col
df = df.iloc[1:] # fix the col names to be the 1st col
# Out:
# /tmp/ipykernel_36924/2543690903.py:1: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.abspath('../data/Nal_filtre_FLX_NEE_01012011_31122017.csv'), encoding = "ISO-8859-1", sep = ';')

# %%
df.head(3)
# Out:
# 0 heure           DateUTC  NEE    Ustar    Swin T_meteo          VPD Tsol1_10  \
# 1     0  01/01/2011 00:00  NaN  0.23159     NaN     NaN          NaN      NaN
# 2   0.5  01/01/2011 00:30  NaN  0.20874  -3.113   18.64  1.569496568   27.385
# 3     1  01/01/2011 01:00  NaN  0.17778  -3.181  17.785  1.453069295    27.14
#
# 0    Hv1    Hv2
# 1  0.038  0.056
# 2  0.038  0.056
# 3  0.038  0.056

# %% [markdown]
# ---

# %% [markdown]
# ### Convert to Numpy

# %%
X = df.iloc[:,2:].values
X = X.astype(float)
print(X.shape)
# Out:
# (122736, 8)

# %% [markdown]
# ---

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ---

# %% [markdown]
# ### Outliers Removal

# %%
Xout = np.abs(X)>3 # we tried with 4, but the number was still so big
X[Xout] = float("nan")
X[Xout] = float("nan")

# %% [markdown]
# ---

# %% [markdown]
# ### Tensor

# %%
X = X[:365 * (len(X)//365) ,] # we are removing the extra days
print(X.shape)
X_tensor = np.reshape(X, (7, -1,8 )) 
print(X_tensor.shape) # (t, rows, cols)
print(X_tensor[0][0])
# Out:
# (122640, 8)
# (7, 17520, 8)
# [        nan  0.0355321          nan         nan         nan         nan
#  -0.89768305 -0.93539032]

# %% [markdown]
# ---

# %% [markdown]
# ### Seasonality

# %%
Xseason = np.nanmean(X_tensor, axis = 0) # so we took the avrage across 7 years
print(Xseason.shape)
print(Xseason[0])
# Out:
# (17520, 8)
# [ 0.33218283 -0.53776708 -0.73200605 -0.6123935   0.25814608 -0.45556883
#  -0.91664538 -0.93539032]
# /tmp/ipykernel_36924/1513193925.py:1: RuntimeWarning: Mean of empty slice
#   Xseason = np.nanmean(X_tensor, axis = 0) # so we took the avrage across 7 years

# %%
plt.plot(Xseason[::48,3])

# %% [markdown]
# ---

# %% [markdown]
# ### Smoothing

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import scipy.signal

# %%
m = 12
alpha = 1/(2*m)

for i in range (8):

    
    fit1 = SimpleExpSmoothing(np.asarray(Xseason[:,i])).fit().fittedvalues
    yhat = scipy.signal.savgol_filter(Xseason[:,i], 50, 3, mode='nearest')
    
    print(fit1.shape)
    plt.plot(Xseason[::48,i])
    plt.plot(yhat[::48], 'r:', lw=2)
    plt.plot(fit1[::48], 'y-', lw=2)
    
    

    plt.show()
# Out:
# (17520,)
# /users/hussein/source/imputation/vImp/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /users/hussein/source/imputation/vImp/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# (17520,)
# (17520,)
# (17520,)
# (17520,)
# (17520,)
# (17520,)
# (17520,)

# %% [markdown]
# ---

# %% [markdown]
# #### Removing Seasonality

# %%
XClean_tensor = X_tensor - Xseason
print(XClean_tensor.shape)
print(XClean_tensor[0][0])
# Out:
# (7, 17520, 8)
# [           nan 5.73299177e-01            nan            nan
#             nan            nan 1.89623302e-02 1.11022302e-16]

# %%
0.0355321-(-0.53776708)
# Out:
# 0.5732991799999999

# %% [markdown]
# ### Create The data

# %%
XClean_np = np.reshape(XClean_tensor, (-1,8) )
XClean_df = pd.DataFrame(XClean_np, columns = df.columns[2:])

# %%
XClean_df
# Out:
# 0       NEE     Ustar      Swin   T_meteo       VPD  Tsol1_10       Hv1  \
# 0       NaN  0.573299       NaN       NaN       NaN       NaN  0.018962
# 1       NaN  0.305922 -0.004173 -0.381933 -0.193158 -0.104793  0.022755
# 2       NaN  0.111600 -0.003097 -0.432981 -0.219921 -0.104099  0.022755
# 3       NaN  0.257217 -0.001565 -0.385913 -0.196866 -0.107106  0.022755
# 4       NaN  0.650464 -0.001658 -0.327528 -0.165273 -0.115434  0.022755
# ...     ...       ...       ...       ...       ...       ...       ...
# 122635  NaN       NaN -0.006003  0.432374  0.207754       NaN -0.011377
# 122636  NaN       NaN -0.003729  0.275716  0.090948       NaN -0.011377
# 122637  NaN       NaN -0.001893  0.240529  0.058388       NaN -0.007585
# 122638  NaN       NaN  0.000560  0.260022  0.059046       NaN -0.007585
# 122639  NaN       NaN  0.000271  0.320365  0.101851       NaN -0.007585
#
# 0                Hv2
# 0       1.110223e-16
# 1       1.110223e-16
# 2       1.110223e-16
# 3       6.913543e-03
# 4       6.913543e-03
# ...              ...
# 122635  3.456772e-02
# 122636  3.802449e-02
# 122637  3.802449e-02
# 122638  3.802449e-02
# 122639  3.802449e-02
#
# [122640 rows x 8 columns]

# %%
import sys

# append the path of the
# parent directory
sys.path.append("..")
from source.utils import create_dic, create_comb, creat_lags

# %%
Xlagged_df = creat_lags(XClean_df, df.columns[2:], [ 0, 48, 1, -1, -48])

# %%
Xlagged_df
# Out:
#         NEE_0  NEE_48  NEE_1  NEE_-1  NEE_-48   Ustar_0  Ustar_48   Ustar_1  \
# 0         NaN     NaN    NaN     NaN      NaN  0.573299       NaN       NaN
# 1         NaN     NaN    NaN     NaN      NaN  0.305922       NaN  0.573299
# 2         NaN     NaN    NaN     NaN      NaN  0.111600       NaN  0.305922
# 3         NaN     NaN    NaN     NaN      NaN  0.257217       NaN  0.111600
# 4         NaN     NaN    NaN     NaN      NaN  0.650464       NaN  0.257217
# ...       ...     ...    ...     ...      ...       ...       ...       ...
# 122635    NaN     NaN    NaN     NaN      NaN       NaN       NaN       NaN
# 122636    NaN     NaN    NaN     NaN      NaN       NaN       NaN       NaN
# 122637    NaN     NaN    NaN     NaN      NaN       NaN       NaN       NaN
# 122638    NaN     NaN    NaN     NaN      NaN       NaN       NaN       NaN
# 122639    NaN     NaN    NaN     NaN      NaN       NaN       NaN       NaN
#
#         Ustar_-1  Ustar_-48  ...     Hv1_0    Hv1_48     Hv1_1    Hv1_-1  \
# 0       0.305922   0.144861  ...  0.018962       NaN       NaN  0.022755
# 1       0.111600   0.357250  ...  0.022755       NaN  0.018962  0.022755
# 2       0.257217   0.351592  ...  0.022755       NaN  0.022755  0.022755
# 3       0.650464   0.252292  ...  0.022755       NaN  0.022755  0.022755
# 4       0.160460   0.305916  ...  0.022755       NaN  0.022755  0.022755
# ...          ...        ...  ...       ...       ...       ...       ...
# 122635       NaN        NaN  ... -0.011377 -0.011377 -0.011377 -0.011377
# 122636       NaN        NaN  ... -0.011377 -0.011377 -0.011377 -0.007585
# 122637       NaN        NaN  ... -0.007585 -0.011377 -0.011377 -0.007585
# 122638       NaN        NaN  ... -0.007585 -0.011377 -0.007585 -0.007585
# 122639       NaN        NaN  ... -0.007585 -0.011377 -0.007585       NaN
#
#          Hv1_-48         Hv2_0    Hv2_48         Hv2_1        Hv2_-1   Hv2_-48
# 0       0.034132  1.110223e-16       NaN           NaN  1.110223e-16 -0.017284
# 1       0.026547  1.110223e-16       NaN  1.110223e-16  1.110223e-16 -0.004033
# 2       0.026547  1.110223e-16       NaN  1.110223e-16  6.913543e-03  0.004033
# 3       0.026547  6.913543e-03       NaN  1.110223e-16  6.913543e-03  0.004033
# 4       0.030972  6.913543e-03       NaN  6.913543e-03  3.456772e-03  0.000000
# ...          ...           ...       ...           ...           ...       ...
# 122635       NaN  3.456772e-02  0.031111  3.111094e-02  3.802449e-02       NaN
# 122636       NaN  3.802449e-02  0.031111  3.456772e-02  3.802449e-02       NaN
# 122637       NaN  3.802449e-02  0.031111  3.802449e-02  3.802449e-02       NaN
# 122638       NaN  3.802449e-02  0.034568  3.802449e-02  3.802449e-02       NaN
# 122639       NaN  3.802449e-02  0.034568  3.802449e-02           NaN       NaN
#
# [122640 rows x 40 columns]

# %%
import numpy as np
test = np.random.rand(365*7*48,8)
# Pad with nan
test1 = np.pad(test, ((49,49),(0,0)),mode='constant',constant_values = (np.nan,np.nan))
test_select = np.concatenate((test1[49:-49,:],test1[0:-98,:],
                              test1[98:,:],test1[48:-50,:],
                             test1[50:-48,:]),axis=1)

# %%
test_select[0]
# Out:
# array([0.56808719, 0.28875717, 0.00861735, 0.23276038, 0.68247351,
#        0.1416181 , 0.38660689, 0.62128443,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan, 0.03088853, 0.25284765, 0.41233652, 0.42011898,
#        0.14205876, 0.52395672, 0.16708254, 0.74616044,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan, 0.65744678, 0.12860979, 0.19123002,
#        0.07110348, 0.64039109, 0.28306946, 0.07624324, 0.85685966])

# %%
test_df = pd.DataFrame(test, columns = df.columns[2:])

# %%
test_select_df = creat_lags(test_df, df.columns[2:])

# %%
test_select_df.values[0]
# Out:
# array([0.56808719,        nan, 0.65744678,        nan, 0.03088853,
#        0.28875717,        nan, 0.12860979,        nan, 0.25284765,
#        0.00861735,        nan, 0.19123002,        nan, 0.41233652,
#        0.23276038,        nan, 0.07110348,        nan, 0.42011898,
#        0.68247351,        nan, 0.64039109,        nan, 0.14205876,
#        0.1416181 ,        nan, 0.28306946,        nan, 0.52395672,
#        0.38660689,        nan, 0.07624324,        nan, 0.16708254,
#        0.62128443,        nan, 0.85685966,        nan, 0.74616044])
